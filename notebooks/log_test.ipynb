# %% [markdown]
# # Ad-hoc analysis of log files using pandas

# %% [markdown]
# Load the required modules.

# %%
from vsc.pbs.job_analysis import PbsLogAnalysis
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# Load configuration file, and add entry for log directory.

# %%
config_file = '../conf/analysis.json'

# %% [markdown]
# Set start and end date for analysis, this will be used to load the appropriate PBS torque log files.

# %%
start_date = '20160615'
end_date = '20160707'

# %% [markdown]
# Create an analysis, and prepare it for use.

# %%
analysis = PbsLogAnalysis(config_file)
analysis.prepare(start_date, end_date)
# Out:
# no log file '/data/leuven/sys/u0065575/pbs_logs/20160707'

# %% [markdown]
# Determine the number of log entries, i.e., jobs that either ended, or started withing the given time period, or, put differently, the number of running jobs.

# %%
len(analysis.jobs)
# Out:
# 7136

# %% [markdown]
# Find first job that has an end event.

# %%
for job_id, job in analysis.jobs.iteritems():
    if len(job.events) >= 4:
        print job_id
        break
# Out:
# 20327734.hpc-p-svcs-10.icts.hpc.kuleuven.be

# %% [markdown]
# Print all events for this job.

# %%
for event in job.events:
    print event
# Out:
# Q: 2016-07-01 10:10:00
#   queue: qdef
# Q: 2016-07-01 10:10:00
#   queue: q21d
# S: 2016-07-01 10:10:35
#   Resource_List.partition: thinking
#   account: lp_hiv_networks
#   group: vsc31147
#   ctime: 1467360600
#   Resource_List.neednodes: 1:ppn=2:ivybridge
#   Resource_List.nodes: 1:ppn=2:ivybridge
#   qtime: 1467360600
#   Resource_List.walltime: 720000
#   jobname: datasetD_run1_010716.pbs
#   queue: q21d
#   start: 1467360635
#   user: vsc31147
#   Resource_List.nodect: 1
#   owner: vsc31147@hpcblade1-hev6.icts.hpc.kuleuven.be
#   Resource_List.pmem: 2621440000
#   etime: 1467360600
#   exec_host: {'r1i0n4': '4-5'}
# E: 2016-07-06 04:22:53
#   total_execution_slots: 2
#   qtime: 1467360600
#   session: 54955
#   owner: vsc31147@hpcblade1-hev6.icts.hpc.kuleuven.be
#   group: vsc31147
#   Exit_status: 0
#   start: 1467360635
#   etime: 1467360600
#   resources_used.cput: 572890
#   Resource_List.nodes: 1:ppn=2:ivybridge
#   unique_node_count: 1
#   exec_host: {'r1i0n4': '4-5'}
#   resources_used.mem: 4980457472
#   Resource_List.walltime: 720000
#   jobname: datasetD_run1_010716.pbs
#   user: vsc31147
#   end: 1467771773
#   Resource_List.pmem: 2621440000
#   resources_used.vmem: 20068106240
#   Resource_List.neednodes: 1:ppn=2:ivybridge
#   resources_used.walltime: 411136
#   Resource_List.partition: thinking
#   account: lp_hiv_networks
#   ctime: 1467360600
#   queue: q21d
#   resources_used.energy_used: 0
#   Resource_List.nodect: 1

# %% [markdown]
# Print some job information.

# %%
print job.name
print job.user
print job.resources_used
print job.exec_host
print 'nodes={0}:ppn={1}'.format(job.resource_spec('nodes')[0]['nodes'], job.resource_spec('nodes')[0]['ppn'])
print job.exit_status
# Out:
# datasetD_run1_010716.pbs
# vsc31147
# {'mem': 4980457472, 'vmem': 20068106240, 'cput': 572890, 'energy_used': '0', 'walltime': 411136}
# {'r1i0n4': '4-5'}
# nodes=1:ppn=2
# 0

# %%
print 'resource specs'
for key, value in job._resource_specs.iteritems():
    print '  {0}: {1}'.format(key, value)
print 'resources used'
for key, value in job._resource_specs.iteritems():
    print '  {0}: {1}'.format(key, value)
# Out:
# resource specs
#   qos: normal
#   features: []
#   neednodes: 1:ppn=2:ivybridge
#   partition: thinking
#   nodect: 1
#   nodes: [{'nodes': 1, 'properties': ['ivybridge'], 'ppn': 2}]
#   pmem: 2621440000
#   walltime: 720000
# resources used
#   qos: normal
#   features: []
#   neednodes: 1:ppn=2:ivybridge
#   partition: thinking
#   nodect: 1
#   nodes: [{'nodes': 1, 'properties': ['ivybridge'], 'ppn': 2}]
#   pmem: 2621440000
#   walltime: 720000

# %% [markdown]
# Compute data frames for jobs and hosts.

# %%
jobs = analysis.jobs_df

# %% [markdown]
# Show the jobs data frame.

# %%
running_jobs_1 = analysis.running_jobs('2016-07-02 20:00:00', '2016-07-02 20:15:00')

# %%
len(running_jobs_1)
# Out:
# 101

# %%
users_1 = set(running_jobs_1.user)

# %%
running_jobs_2 = analysis.running_jobs('2016-07-05 16:00:00', '2016-07-02 16:15:00')

# %%
users_2 = set(running_jobs_2.user)

# %%
users_1.intersection(users_2)
# Out:
# {'vsc30517', 'vsc30767', 'vsc30957', 'vsc31147', 'vsc31514', 'vsc31562'}

# %%
running_jobs_1[running_jobs_1.user == 'vsc30767'][['start', 'end', 'nodes', 'ppn', 'exit_status']]
# Out:
#                  start                 end  nodes  ppn  exit_status
# 19 2016-06-30 11:43:54 2016-07-06 14:58:09     16   24            0
# 70 2016-07-02 18:57:11 2016-07-03 18:57:24     10   20          -11

# %%
running_jobs_2[running_jobs_2.user == 'vsc30767'][['start', 'end', 'nodes', 'ppn', 'exit_status']]
# Out:
#                 start                 end  nodes  ppn  exit_status
# 5 2016-06-30 11:43:54 2016-07-06 14:58:09     16   24            0

# %% [markdown]
# How many jobs were running in the GPU partition on June 7 and 8?

# %%
len(jobs[jobs['partition'] == 'gpu'])
# Out:
# 122

# %% [markdown]
# How many distinct users where active on June 7 and 8?

# %%
len(set(jobs['user']))
# Out:
# 167

# %% [markdown]
# List jobs for a particular user.

# %%
jobs[jobs['user'] == 'vsc41730']
# Out:
#                     time                                       job_id  \
# 6627 2016-06-23 23:47:33  20325962.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 6628 2016-06-23 23:47:33  20325962.hpc-p-svcs-10.icts.hpc.kuleuven.be
#
#           user state partition  used_mem used_walltime spec_walltime  nodes  \
# 6627  vsc41730     E  thinking       NaN          None      24:00:00      2
# 6628  vsc41730     S  thinking       NaN          None      24:00:00      2
#
#       ppn hosts  exit_status
# 6627   10  None            0
# 6628   10  None            0

# %% [markdown]
# Show the host data frame.

# %%
hosts = analysis.hosts_df

# %% [markdown]
# Which jobs ran on node `r3i1n14`?

# %%
pd.merge(jobs, hosts[hosts['host'] == 'r3i1n14'],
         how='inner', left_on='job_id', right_on='job_id')
# Out:
#                    time                                       job_id  \
# 0   2016-06-17 11:10:02  20322769.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 1   2016-06-17 12:11:51  20322769.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 2   2016-06-17 14:11:27  20322778.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 3   2016-06-17 15:13:15  20322778.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 4   2016-06-17 16:04:23  20322576.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 5   2016-06-17 16:04:41  20322576.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 6   2016-06-19 12:03:10  20323130.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 7   2016-06-19 17:40:41  20323130.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 8   2016-06-19 19:45:24  20323217.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 9   2016-06-19 21:00:14  20323217.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 10  2016-06-19 23:05:19  20323255.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 11  2016-06-19 23:06:54  20323255.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 12  2016-06-19 23:07:31  20323262.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 13  2016-06-19 23:09:06  20323262.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 14  2016-06-19 23:09:31  20323268.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 15  2016-06-19 23:10:59  20323268.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 16  2016-06-19 23:11:03  20323273.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 17  2016-06-19 23:12:26  20323273.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 18  2016-06-19 23:12:40  20323279.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 19  2016-06-19 23:14:15  20323279.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 20  2016-06-19 23:15:03  20323288.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 21  2016-06-19 23:16:35  20323288.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 22  2016-06-19 23:22:34  20323294.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 23  2016-06-19 23:54:37  20323294.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 24  2016-06-20 01:21:33  20323423.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 25  2016-06-21 15:35:49  20323423.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 26  2016-06-21 15:36:36  20324191.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 27  2016-06-22 06:38:00  20324191.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 28  2016-06-22 09:56:59  20324720.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 29  2016-06-22 09:57:04  20324720.hpc-p-svcs-10.icts.hpc.kuleuven.be
# ..                  ...                                          ...
# 81  2016-06-30 15:10:47  20327451.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 82  2016-06-30 15:21:37  20327481.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 83  2016-06-30 15:24:17  20327481.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 84  2016-06-30 15:34:28  20327500.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 85  2016-06-30 16:29:36  20327500.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 86  2016-06-30 16:34:30  20327576.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 87  2016-06-30 16:35:05  20327576.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 88  2016-06-30 16:36:36  20327564.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 89  2016-06-30 21:36:43  20327564.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 90  2016-07-01 15:06:28  20327825.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 91  2016-07-02 00:36:25  20327825.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 92  2016-07-02 02:20:09  20327981.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 93  2016-07-06 01:09:30  20327981.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 94  2016-07-06 10:04:37  20329358.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 95  2016-07-06 10:05:39  20329358.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 96  2016-07-06 10:18:54  20329402.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 97  2016-07-06 10:33:27  20329402.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 98  2016-07-06 10:43:30  20329414.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 99  2016-07-06 10:57:45  20329414.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 100 2016-07-06 11:03:14  20329423.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 101 2016-07-06 11:12:59  20329423.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 102 2016-07-06 11:22:59  20329432.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 103 2016-07-06 11:31:00  20329432.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 104 2016-07-06 11:44:53  20329443.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 105 2016-07-06 11:52:45  20329443.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 106 2016-07-06 11:59:49  20329456.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 107 2016-07-06 12:08:04  20329456.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 108 2016-07-06 12:15:44  20329482.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 109 2016-07-06 16:03:08  20329482.hpc-p-svcs-10.icts.hpc.kuleuven.be
# 110 2016-07-06 16:04:59  20329608.hpc-p-svcs-10.icts.hpc.kuleuven.be
#
#          user state partition  used_mem used_walltime spec_walltime  nodes  \
# 0    vsc30002     S  thinking     240.6      01:00:10      01:00:00     50
# 1    vsc30002     E  thinking     240.6      01:00:10      01:00:00     50
# 2    vsc30002     S  thinking     233.0      01:00:12      01:00:00     47
# 3    vsc30002     E  thinking     233.0      01:00:12      01:00:00     47
# 4    vsc31461     S  thinking       0.0      00:00:16      00:55:00      1
# 5    vsc31461     E  thinking       0.0      00:00:16      00:55:00      1
# 6    vsc31004     S  thinking       6.1      05:37:29      72:00:00      1
# 7    vsc31004     E  thinking       6.1      05:37:29      72:00:00      1
# 8    vsc31081     S  thinking       1.6      01:14:49      03:00:00      1
# 9    vsc31081     E  thinking       1.6      01:14:49      03:00:00      1
# 10   vsc31196     S  thinking       1.3      00:01:35      01:00:00      1
# 11   vsc31196     E  thinking       1.3      00:01:35      01:00:00      1
# 12   vsc31196     S  thinking       1.3      00:01:33      01:00:00      1
# 13   vsc31196     E  thinking       1.3      00:01:33      01:00:00      1
# 14   vsc31196     S  thinking       1.0      00:01:26      01:00:00      1
# 15   vsc31196     E  thinking       1.0      00:01:26      01:00:00      1
# 16   vsc31196     S  thinking       1.0      00:01:21      01:00:00      1
# 17   vsc31196     E  thinking       1.0      00:01:21      01:00:00      1
# 18   vsc31196     S  thinking       1.3      00:01:34      01:00:00      1
# 19   vsc31196     E  thinking       1.3      00:01:34      01:00:00      1
# 20   vsc31196     S  thinking       1.2      00:01:30      01:00:00      1
# 21   vsc31196     E  thinking       1.2      00:01:30      01:00:00      1
# 22   vsc31196     S  thinking       1.4      00:32:01      01:00:00      1
# 23   vsc31196     E  thinking       1.4      00:32:01      01:00:00      1
# 24   vsc30517     S  thinking      12.3      38:14:14     168:00:00      1
# 25   vsc30517     E  thinking      12.3      38:14:14     168:00:00      1
# 26   vsc30709     S  thinking      45.4      15:01:23      24:00:00      1
# 27   vsc30709     E  thinking      45.4      15:01:23      24:00:00      1
# 28   vsc31435     S  thinking       4.6      00:01:15      72:00:00     18
# 29   vsc31435     E  thinking       4.6      00:01:15      72:00:00     18
# ..        ...   ...       ...       ...           ...           ...    ...
# 81   vsc31435     E  thinking       4.7      00:02:31      24:00:00     18
# 82   vsc31435     S  thinking       4.6      00:02:37      24:00:00     18
# 83   vsc31435     E  thinking       4.6      00:02:37      24:00:00     18
# 84   vsc30864     S  thinking      28.8      00:55:05      24:00:00      2
# 85   vsc30864     E  thinking      28.8      00:55:05      24:00:00      2
# 86   vsc31196     S  thinking       0.0      00:00:34      01:00:00      1
# 87   vsc31196     E  thinking       0.0      00:00:34      01:00:00      1
# 88   vsc31291     S  thinking       1.4      05:00:03      05:00:00      6
# 89   vsc31291     E  thinking       1.4      05:00:03      05:00:00      6
# 90   vsc30864     S  thinking      29.7      09:29:54      72:00:00      2
# 91   vsc30864     E  thinking      29.7      09:29:54      72:00:00      2
# 92   vsc30517     S  thinking       6.1      94:49:14     504:00:00      1
# 93   vsc30517     E  thinking       6.1      94:49:14     504:00:00      1
# 94   vsc31056     S  thinking       0.2      00:01:02      01:00:00      1
# 95   vsc31056     E  thinking       0.2      00:01:02      01:00:00      1
# 96   vsc31056     S  thinking       0.2      00:14:32      01:00:00      1
# 97   vsc31056     E  thinking       0.2      00:14:32      01:00:00      1
# 98   vsc31056     S  thinking       0.2      00:14:13      01:00:00      1
# 99   vsc31056     E  thinking       0.2      00:14:13      01:00:00      1
# 100  vsc31056     S  thinking       0.5      00:09:44      01:00:00      1
# 101  vsc31056     E  thinking       0.5      00:09:44      01:00:00      1
# 102  vsc30637     S  thinking      26.4      00:07:59      01:00:00      1
# 103  vsc30637     E  thinking      26.4      00:07:59      01:00:00      1
# 104  vsc30637     S  thinking      26.5      00:07:50      01:00:00      1
# 105  vsc30637     E  thinking      26.5      00:07:50      01:00:00      1
# 106  vsc30637     S  thinking      26.8      00:08:14      01:00:00      1
# 107  vsc30637     E  thinking      26.8      00:08:14      01:00:00      1
# 108  vsc30625     S  thinking      44.5      03:47:20      30:00:00      4
# 109  vsc30625     E  thinking      44.5      03:47:20      30:00:00      4
# 110  vsc31056     S  thinking       NaN          None      01:00:00      1
#
#      ppn                                              hosts  exit_status  \
# 0     20  r3i0n14 r3i0n15 r3i0n10 r3i0n11 r3i0n12 r3i0n1...          -11
# 1     20  r3i0n14 r3i0n15 r3i0n10 r3i0n11 r3i0n12 r3i0n1...          -11
# 2     20  r3i1n8 r3i0n14 r3i0n15 r3i0n10 r3i0n11 r3i0n12...          -11
# 3     20  r3i1n8 r3i0n14 r3i0n15 r3i0n10 r3i0n11 r3i0n12...          -11
# 4     20                                            r3i1n14            0
# 5     20                                            r3i1n14            0
# 6     20                                            r3i1n14            0
# 7     20                                            r3i1n14            0
# 8     20                                            r3i1n14            0
# 9     20                                            r3i1n14            0
# 10    20                                            r3i1n14            1
# 11    20                                            r3i1n14            1
# 12    20                                            r3i1n14            1
# 13    20                                            r3i1n14            1
# 14    20                                            r3i1n14            0
# 15    20                                            r3i1n14            0
# 16    20                                            r3i1n14            1
# 17    20                                            r3i1n14            1
# 18    20                                            r3i1n14            1
# 19    20                                            r3i1n14            1
# 20    20                                            r3i1n14            1
# 21    20                                            r3i1n14            1
# 22    20                                            r3i1n14            1
# 23    20                                            r3i1n14            1
# 24    20                                            r3i1n14            0
# 25    20                                            r3i1n14            0
# 26    20                                            r3i1n14            0
# 27    20                                            r3i1n14            0
# 28    20  r3i1n11 r3i2n1 r3i1n16 r3i0n14 r3i0n15 r3i0n4 ...          271
# 29    20  r3i1n11 r3i2n1 r3i1n16 r3i0n14 r3i0n15 r3i0n4 ...          271
# ..   ...                                                ...          ...
# 81    20  r1i2n2 r1i2n3 r3i2n14 r3i2n15 r1i2n6 r3i2n13 r...            1
# 82    20  r3i2n16 r3i1n2 r3i2n14 r3i2n15 r1i2n6 r3i2n13 ...            1
# 83    20  r3i2n16 r3i1n2 r3i2n14 r3i2n15 r1i2n6 r3i2n13 ...            1
# 84    20                                     r3i1n2 r3i1n14            0
# 85    20                                     r3i1n2 r3i1n14            0
# 86    20                                            r3i1n14            1
# 87    20                                            r3i1n14            1
# 88    20      r3i2n16 r3i1n2 r5i0n12 r3i1n14 r3i1n15 r4i0n2          -11
# 89    20      r3i2n16 r3i1n2 r5i0n12 r3i1n14 r3i1n15 r4i0n2          -11
# 90    20                                    r3i1n15 r3i1n14            0
# 91    20                                    r3i1n15 r3i1n14            0
# 92    10                                            r3i1n14            0
# 93    10                                            r3i1n14            0
# 94     2                                            r3i1n14            0
# 95     2                                            r3i1n14            0
# 96     2                                            r3i1n14            0
# 97     2                                            r3i1n14            0
# 98     2                                            r3i1n14            0
# 99     2                                            r3i1n14            0
# 100    4                                            r3i1n14            0
# 101    4                                            r3i1n14            0
# 102    1                                            r3i1n14            0
# 103    1                                            r3i1n14            0
# 104    1                                            r3i1n14            0
# 105    1                                            r3i1n14            0
# 106    1                                            r3i1n14            0
# 107    1                                            r3i1n14            0
# 108   20                     r3i0n14 r3i0n11 r3i2n2 r3i1n14            1
# 109   20                     r3i0n14 r3i0n11 r3i2n2 r3i1n14            1
# 110    4                                            r3i1n14        -1024
#
#         host cores
# 0    r3i1n14  0-19
# 1    r3i1n14  0-19
# 2    r3i1n14  0-19
# 3    r3i1n14  0-19
# 4    r3i1n14  0-19
# 5    r3i1n14  0-19
# 6    r3i1n14  0-19
# 7    r3i1n14  0-19
# 8    r3i1n14  0-19
# 9    r3i1n14  0-19
# 10   r3i1n14  0-19
# 11   r3i1n14  0-19
# 12   r3i1n14  0-19
# 13   r3i1n14  0-19
# 14   r3i1n14  0-19
# 15   r3i1n14  0-19
# 16   r3i1n14  0-19
# 17   r3i1n14  0-19
# 18   r3i1n14  0-19
# 19   r3i1n14  0-19
# 20   r3i1n14  0-19
# 21   r3i1n14  0-19
# 22   r3i1n14  0-19
# 23   r3i1n14  0-19
# 24   r3i1n14  0-19
# 25   r3i1n14  0-19
# 26   r3i1n14  0-19
# 27   r3i1n14  0-19
# 28   r3i1n14  0-19
# 29   r3i1n14  0-19
# ..       ...   ...
# 81   r3i1n14  0-19
# 82   r3i1n14  0-19
# 83   r3i1n14  0-19
# 84   r3i1n14  0-19
# 85   r3i1n14  0-19
# 86   r3i1n14  0-19
# 87   r3i1n14  0-19
# 88   r3i1n14  0-19
# 89   r3i1n14  0-19
# 90   r3i1n14  0-19
# 91   r3i1n14  0-19
# 92   r3i1n14   0-9
# 93   r3i1n14   0-9
# 94   r3i1n14   0-1
# 95   r3i1n14   0-1
# 96   r3i1n14   0-1
# 97   r3i1n14   0-1
# 98   r3i1n14   0-1
# 99   r3i1n14   0-1
# 100  r3i1n14   0-3
# 101  r3i1n14   0-3
# 102  r3i1n14     0
# 103  r3i1n14     0
# 104  r3i1n14     0
# 105  r3i1n14     0
# 106  r3i1n14     0
# 107  r3i1n14     0
# 108  r3i1n14  0-19
# 109  r3i1n14  0-19
# 110  r3i1n14   0-3
#
# [111 rows x 14 columns]
